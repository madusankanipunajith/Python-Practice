# %%
import spacy

# %%
english_nlp = spacy.load('en_core_web_sm')

# %%
document = english_nlp(u'Apple is valued at $3 Billion company')

# %%
document
# Out:
# Apple is valued at $3 Billion company

# %%
for token in document:
  print(token.text)
# Out:
# Apple
# is
# valued
# at
# $
# 3
# Billion
# company

# %%
document[0]
# Out:
# Apple

# %%
type(document)
# Out:
# spacy.tokens.doc.Doc
